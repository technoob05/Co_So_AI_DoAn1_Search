# %% [markdown]
# # 1. Test Functions - Các hàm kiểm tra
#
# Notebook này giới thiệu các hàm test được sử dụng để đánh giá thuật toán tối ưu hóa.

# %%
import numpy as np
import sys
sys.path.append('..')

from src.test_functions import get_test_function
from src.visualization import OptimizationVisualizer

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Visualize Test Functions
#
# Dưới đây là visualization của các hàm test function trong không gian 2D

# %%
# Visualize all test functions
functions = ['sphere', 'rastrigin', 'rosenbrock', 'ackley']

for func_name in functions:
    func_2d = get_test_function(func_name, dim=2)
    print(f"\n{func_name.upper()} Function")
    print(f"Global optimum: {func_2d.global_optimum}")
    OptimizationVisualizer.plot_3d_surface(func_2d, x_range=(-5, 5), y_range=(-5, 5))
